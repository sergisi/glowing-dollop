# %%
import mytools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pathlib as pl

# %%
from collections import defaultdict

# %%
p = pl.Path('../output/vars/200-8/')
dfs =[pd.read_csv(x) for x in p.iterdir()]

# %%
dfs
# Out:
# [     initial_weight  weight  none-anonymity       mean   mean-min   max-mean  \
#  0               135       1               0  14.825355  13.025355  19.174645
#  1               135       1               0  14.807932  12.593646  24.192068
#  2               135       1               0  15.077010  13.077010  21.922990
#  3               135       1               0  14.747873  12.547873  21.252127
#  4               135       1               0  14.905781  12.605781  24.094219
#  ..              ...     ...             ...        ...        ...        ...
#  194             135       1               0  14.832921  12.261493  19.167079
#  195             135       1               0  14.965966  12.751680  20.034034
#  196             135       1               0  14.913665  12.580331  23.086335
#  197             135       1               0  15.037915  13.237915  17.962085
#  198             135       1               0  14.797264  12.566495  23.202736
#
# ...

# %%
mytools.get_stats((1,dfs))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-824d0567388c> in <module>
# ----> 1 mytools.get_stats((1,dfs))
#
# ~/uni/cig/glowing-dollop/notebook/mytools.py in get_stats(dsi)
#       9     stats = defaultdict(lambda: defaultdict(lambda: None))
#      10     for df in dsi:
# ---> 11         iw, costw, an, meann, meanm, mediann, medianm = df.mean()
#      12         stats[costw][iw] = {'initial-w':iw, 'k':i, 'costw':costw,'none-anonymity': an,'mean-min': meann,'max-mean': meanm,'median-mean': mediann,'max-median': medianm}
#      13     return stats
#
# ValueError: too many values to unpack (expected 7)
